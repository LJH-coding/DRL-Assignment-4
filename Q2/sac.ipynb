# %%
import matplotlib.pyplot as plt
import numpy as np

import torch
import torch.optim as optim
import torch.nn.functional as F
from torch import nn

device = "cpu"
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import gymnasium as gym
from gymnasium.wrappers import RecordEpisodeStatistics
import sys
sys.path.append('..')  # access dmc in parent dir
from dmc import make_dmc_env

def make_env():
	def thunk():
		# Create environment with state observations
		env_name = "cartpole-balance"
		env = make_dmc_env(env_name, np.random.randint(0, 1000000), flatten=True, use_pixels=False)
		# warppers
		env = RecordEpisodeStatistics(env, buffer_length=1000)
		return env

	return thunk
# Out:
# /tmp2/b10902111/miniconda3/envs/rl/lib/python3.10/site-packages/glfw/__init__.py:917: GLFWError: (65550) b'Failed to detect any supported platform'
#   warnings.warn(message, GLFWError)
# /tmp2/b10902111/miniconda3/envs/rl/lib/python3.10/site-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists

# %%
env = make_env()()
print(f'''
[Action]
     {env.action_space}: {env.action_space.sample()}
[Observation]
     {env.observation_space}: {env.observation_space.sample()}
'''.strip())
env.close()
# Out:
# [Action]
#      Box(-1.0, 1.0, (1,), float64): [-0.26513782]
# [Observation]
#      Box(-inf, inf, (5,), float64): [ 1.45682798  0.43805428 -0.3762297   1.03003791 -1.42336689]

# %% [markdown]
# # Networks

# %%
class Qnet(nn.Module):
    def __init__(self, envs) -> None:
        super(Qnet, self).__init__()
        n_observation = int(np.prod(envs.single_observation_space.shape))
        n_action = int(np.prod(envs.single_action_space.shape))

        self.fc = nn.Sequential(
            nn.Linear(n_observation + n_action, 32),
            nn.ReLU(),
            nn.Linear(32, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
        )

    def forward(self, state: torch.Tensor, action: torch.Tensor) -> torch.Tensor:
        state_action = torch.cat([state, action], dim=1)
        return self.fc(state_action)

# %%
envs = gym.vector.SyncVectorEnv([make_env()])
torch.jit.script(Qnet(envs))
# Out:
# RecursiveScriptModule(
#   original_name=Qnet
#   (fc): RecursiveScriptModule(
#     original_name=Sequential
#     (0): RecursiveScriptModule(original_name=Linear)
#     (1): RecursiveScriptModule(original_name=ReLU)
#     (2): RecursiveScriptModule(original_name=Linear)
#     (3): RecursiveScriptModule(original_name=ReLU)
#     (4): RecursiveScriptModule(original_name=Linear)
#   )
# )

# %%
# reference: ClearRL
class Actor(nn.Module):
    def __init__(self, envs) -> None:
        super().__init__()
        n_observation = int(np.prod(envs.single_observation_space.shape))
        n_action = int(np.prod(envs.single_action_space.shape))
        action_high = envs.single_action_space.high
        action_low = envs.single_action_space.low

        self.fc = nn.Sequential(
            nn.Linear(n_observation, 32),
            nn.ReLU(),
            nn.Linear(32, 32),
            nn.ReLU(),
        )
        self.fc_mean = nn.Linear(32, n_action)
        self.fc_logstd = nn.Linear(32, n_action) # log std is more stable
        self.LOG_STD_MAX = 2
        self.LOG_STD_MIN = -5  # maybe -20

        # action rescaling
        self.register_buffer(
            "action_scale",
            torch.tensor((action_high - action_low) / 2.0, dtype=torch.float32),
        )
        self.register_buffer(
            "action_bias",
            torch.tensor((action_high + action_low) / 2.0, dtype=torch.float32),
        )

    def forward(self, state: torch.Tensor) -> tuple:
        # get mean, std
        x = self.fc(state)
        mean = self.fc_mean(x)
        log_std = self.fc_logstd(x)
        log_std = torch.tanh(log_std)
        log_std = self.LOG_STD_MIN + 0.5 * (self.LOG_STD_MAX - self.LOG_STD_MIN) * (log_std + 1)
        std = log_std.exp()

        # get action, log_prob
        normal = torch.distributions.Normal(mean, std)
        x_t = normal.rsample()  # for reparameterization trick (mean + std * N(0,1))
        y_t = torch.tanh(x_t) # output between [-1, 1]
        action = y_t * self.action_scale + self.action_bias
        log_prob = normal.log_prob(x_t)
        # Enforcing Action Bound
        log_prob -= torch.log(self.action_scale * (1 - y_t.pow(2)) + 1e-6)
        log_prob = log_prob.sum(1, keepdim=True)
        # mean is deterministic action
        mean = torch.tanh(mean) * self.action_scale + self.action_bias
        return action, log_prob, mean

# %%
obs = envs.single_observation_space.sample()
sample_input = torch.tensor(np.array([obs]), device=device, dtype=torch.float32)
torch.jit.trace(Actor(envs).to(device), sample_input)
env.close()
# Out:
# /tmp2/b10902111/miniconda3/envs/rl/lib/python3.10/site-packages/torch/jit/_trace.py:1307: TracerWarning: Trace had nondeterministic nodes. Did you forget call .eval() on your model? Nodes:
# 	%eps : Float(1, 1, strides=[1, 1], requires_grad=0, device=cpu) = aten::normal(%73, %81, %82) # /tmp2/b10902111/miniconda3/envs/rl/lib/python3.10/site-packages/torch/distributions/utils.py:63:0
# This may cause errors in trace checking. To disable trace checking, pass check_trace=False to torch.jit.trace()
#   _check_trace(
# /tmp2/b10902111/miniconda3/envs/rl/lib/python3.10/site-packages/torch/jit/_trace.py:1307: TracerWarning: Output nr 1. of the traced function does not match the corresponding output of the Python function. Detailed error:
# Tensor-likes are not close!
#
# Mismatched elements: 1 / 1 (100.0%)
# Greatest absolute difference: 0.2615000605583191 at index (0, 0) (up to 1e-05 allowed)
# Greatest relative difference: 1.8931899962511562 at index (0, 0) (up to 1e-05 allowed)
#   _check_trace(
# /tmp2/b10902111/miniconda3/envs/rl/lib/python3.10/site-packages/torch/jit/_trace.py:1307: TracerWarning: Output nr 2. of the traced function does not match the corresponding output of the Python function. Detailed error:
# Tensor-likes are not close!
#
# Mismatched elements: 1 / 1 (100.0%)
# Greatest absolute difference: 0.3294490575790405 at index (0, 0) (up to 1e-05 allowed)
# Greatest relative difference: 0.45240883621917416 at index (0, 0) (up to 1e-05 allowed)
#   _check_trace(

# %% [markdown]
# # Agent

# %%
import os
from tensordict import tensorclass
from torchrl.data import ReplayBuffer, LazyTensorStorage


@tensorclass
class Transition:
    observation: torch.Tensor
    action: torch.Tensor
    reward: torch.Tensor
    next_obs: torch.Tensor
    done: torch.Tensor


class SACAgent:
    def __init__(
        self,
        envs,
        q_learning_rate: float = 1e-3,
        actor_learning_rate: float = 3e-4,
        replay_buffer_size: int = 20000,
        batch_size: int = 64,
        gamma: float = 0.99,
        tau: float = 5e-3,
        policy_update_freq: float = 2,
        target_update_freq: float = 2,
        use_jit: bool = True,
    ):
        self.use_jit = use_jit

        # networks
        self.actor = Actor(envs).to(device)
        self.q1 = Qnet(envs).to(device)
        self.q2 = Qnet(envs).to(device)
        self.target_q1 = Qnet(envs).to(device)
        self.target_q2 = Qnet(envs).to(device)
        self.target_q1.load_state_dict(self.q1.state_dict())
        self.target_q2.load_state_dict(self.q2.state_dict())
        if use_jit:
            self._make_jit_models(envs)
        self.target_q1.eval()
        self.target_q2.eval()

        self.q_optimizer = optim.Adam(
            list(self.q1.parameters()) + list(self.q2.parameters()), lr=q_learning_rate
        )
        self.actor_optimizer = optim.Adam(
            self.actor.parameters(), lr=actor_learning_rate
        )

        # automatic alpha tuning
        self.TARGET_ENTROPY = -torch.prod(torch.Tensor(env.action_space.shape).to(device)).item()
        self.log_alpha = torch.zeros(1, requires_grad=True, device=device) # log is more stable
        self.alpha = self.log_alpha.exp().item()
        self.alpha_optimizer = optim.Adam([self.log_alpha], lr=q_learning_rate)

        # hyperparameters
        self.gamma = gamma
        self.tau = tau
        self.policy_update_freq = policy_update_freq
        self.target_update_freq = target_update_freq
        self.replay_buffer = ReplayBuffer(
            storage=LazyTensorStorage(replay_buffer_size, device=device),
            batch_size=batch_size,
            prefetch=10,
        )
    
    def _make_jit_models(self, envs) -> None:
        obs = envs.single_observation_space.sample()
        sample_input = torch.tensor([obs], device=device, dtype=torch.float32)
        self.actor = torch.jit.trace(self.actor, sample_input)
        self.q1 = torch.jit.script(self.q1)
        self.q2 = torch.jit.script(self.q2)
        self.target_q1 = torch.jit.script(self.target_q1)
        self.target_q2 = torch.jit.script(self.target_q2)
    
    def _update_q(self, batch: Transition) -> None:
        with torch.no_grad():
            sampled_action, log_prob, _ = self.actor(batch.next_obs)
            q_value_1 = self.target_q1(batch.next_obs, sampled_action)
            q_value_2 = self.target_q2(batch.next_obs, sampled_action)
            min_q_value = torch.min(q_value_1, q_value_2) - self.alpha * log_prob
            target_q_value = batch.reward + self.gamma * (1 - batch.done) * min_q_value

        q1_value = self.q1(batch.observation, batch.action)
        q2_value = self.q2(batch.observation, batch.action)
        q1_loss = F.mse_loss(q1_value, target_q_value)
        q2_loss = F.mse_loss(q2_value, target_q_value)
        total_q_loss = q1_loss + q2_loss

        self.q_optimizer.zero_grad()
        total_q_loss.backward()
        self.q_optimizer.step()

    def _update_actor(self, batch: Transition) -> None:
        sampled_action, log_prob, _ = self.actor(batch.observation)
        q_value_1 = self.q1(batch.observation, sampled_action)
        q_value_2 = self.q2(batch.observation, sampled_action)
        min_q_value = torch.min(q_value_1, q_value_2)  # detach?
        loss = (self.alpha * log_prob - min_q_value).mean()

        self.actor_optimizer.zero_grad()
        loss.backward()
        self.actor_optimizer.step()

        # automatic alpha tuning
        with torch.no_grad():
            _, log_prob, _ = self.actor(batch.observation)
        alpha_loss = (-self.log_alpha.exp() * (log_prob + self.TARGET_ENTROPY)).mean()

        self.alpha_optimizer.zero_grad()
        alpha_loss.backward()
        self.alpha_optimizer.step()
        self.alpha = self.log_alpha.exp().item()

    def _update_target_net(self) -> None:
        for param, target_param in zip(self.q1.parameters(), self.target_q1.parameters()):
            target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)
        for param, target_param in zip(self.q2.parameters(), self.target_q2.parameters()):
            target_param.data.copy_(self.tau * param.data + (1 - self.tau) * target_param.data)

    def learn(self, global_step: int) -> None:
        batch = self.replay_buffer.sample()
        self._update_q(batch)
        if global_step % self.policy_update_freq == 0:
            for _ in range(self.policy_update_freq):
                self._update_actor(batch)
        if global_step % self.target_update_freq == 0:
            self._update_target_net()
    
    def get_action(self, observation: torch.Tensor):
        sampled_action, _, _ = self.actor(observation)
        return sampled_action.detach().cpu().numpy()
    
    def memorize(self, transition: Transition) -> None:
        self.replay_buffer.extend(transition)
    
    def save(self, dir_name: str) -> None:
        os.makedirs(dir_name, exist_ok=True)

        if self.use_jit:
            torch.jit.save(self.actor, f"{dir_name}/actor.pt")
            torch.jit.save(self.q1, f"{dir_name}/q1.pt")
            torch.jit.save(self.q2, f"{dir_name}/q2.pt")
        else:
            torch.save(self.actor.state_dict(), f"{dir_name}/actor.pt")
            torch.save(self.q1.state_dict(), f"{dir_name}/q1.pt")
            torch.save(self.q2.state_dict(), f"{dir_name}/q2.pt")

    def load(self, dir_name: str) -> None:
        if self.use_jit:
            self.actor = torch.jit.load(f"{dir_name}/actor.pt", map_location=device)
            self.q1 = torch.jit.load(f"{dir_name}/q1.pt", map_location=device)
            self.q2 = torch.jit.load(f"{dir_name}/q2.pt", map_location=device)
        else:
            self.actor.load_state_dict(torch.load(f"{dir_name}/actor.pt", map_location=device))
            self.q1.load_state_dict(torch.load(f"{dir_name}/q1.pt", map_location=device))
            self.q2.load_state_dict(torch.load(f"{dir_name}/q2.pt", map_location=device))
        
        self.target_q1.load_state_dict(self.q1.state_dict())
        self.target_q2.load_state_dict(self.q2.state_dict())
    
    def eval(self) -> None:
        self.actor.eval()
        self.q1.eval()
        self.q2.eval()
    
    def train(self) -> None:
        self.actor.train()
        self.q1.train()
        self.q2.train()

# %% [markdown]
# # Training

# %%
num_envs = 2
envs = gym.vector.SyncVectorEnv(
    [make_env() for _ in range(num_envs)]
)
agent = SACAgent(envs)
# Out:
# /tmp/ipykernel_2108349/350529683.py:70: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:254.)
#   sample_input = torch.tensor([obs], device=device, dtype=torch.float32)
# /tmp2/b10902111/miniconda3/envs/rl/lib/python3.10/site-packages/torch/jit/_trace.py:1307: TracerWarning: Trace had nondeterministic nodes. Did you forget call .eval() on your model? Nodes:
# 	%eps : Float(1, 1, strides=[1, 1], requires_grad=0, device=cpu) = aten::normal(%73, %81, %82) # /tmp2/b10902111/miniconda3/envs/rl/lib/python3.10/site-packages/torch/distributions/utils.py:63:0
# This may cause errors in trace checking. To disable trace checking, pass check_trace=False to torch.jit.trace()
#   _check_trace(
# /tmp2/b10902111/miniconda3/envs/rl/lib/python3.10/site-packages/torch/jit/_trace.py:1307: TracerWarning: Output nr 1. of the traced function does not match the corresponding output of the Python function. Detailed error:
# Tensor-likes are not close!
#
# Mismatched elements: 1 / 1 (100.0%)
# Greatest absolute difference: 0.005906969308853149 at index (0, 0) (up to 1e-05 allowed)
# Greatest relative difference: 0.013325957402520424 at index (0, 0) (up to 1e-05 allowed)
#   _check_trace(
# /tmp2/b10902111/miniconda3/envs/rl/lib/python3.10/site-packages/torch/jit/_trace.py:1307: TracerWarning: Output nr 2. of the traced function does not match the corresponding output of the Python function. Detailed error:
# Tensor-likes are not close!
#
# Mismatched elements: 1 / 1 (100.0%)
# Greatest absolute difference: 0.00502343475818634 at index (0, 0) (up to 1e-05 allowed)
# Greatest relative difference: 0.046659243455267306 at index (0, 0) (up to 1e-05 allowed)
#   _check_trace(

# %%
total_steps = 100000
warm_up_steps = 1000
returns = []

observations, info = envs.reset()
observations = torch.tensor(observations, device=device, dtype=torch.float32)
for step in range(1, total_steps + 1):
    # select action and act
    if step < warm_up_steps:
        actions = envs.action_space.sample().astype(np.float32)
    else:
        actions = agent.get_action(observations)
    next_obss, rewards, terminated, truncated, info = envs.step(actions)
    next_obss = torch.tensor(next_obss, device=device, dtype=torch.float32)
    done = (terminated | truncated)

    # save transition to replay buffer
    transitions = Transition(
        observation = observations,
        action = torch.tensor(actions, dtype=torch.float32),
        reward = torch.tensor(rewards, dtype=torch.float32).unsqueeze_(-1),
        next_obs = next_obss,
        done = torch.tensor(terminated, dtype=torch.float32).unsqueeze_(-1),
        batch_size=[num_envs],
    )
    agent.memorize(transitions)

    # update models
    if step > warm_up_steps:
        agent.learn(step)

    if any(done):
        # log
        print(f"[{step}], alpha={agent.alpha:.3f}, {info['episode']}")
        returns.extend(info["episode"]["r"].tolist())
        observations, info = envs.reset()
        observations = torch.tensor(observations, device=device, dtype=torch.float32)
        continue

    observations = next_obss
# Out:
# [1000], alpha=1.000, {'r': array([365.2269311 , 359.48913198]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([1.9424  , 1.942327]), '_t': array([ True,  True])}
# [2000], alpha=0.431, {'r': array([334.5877714 , 362.37265878]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.21355 , 11.213538]), '_t': array([ True,  True])}
# [3000], alpha=0.232, {'r': array([259.14605446, 395.54308945]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.60487 , 10.604853]), '_t': array([ True,  True])}
# [4000], alpha=0.138, {'r': array([399.80000495, 396.90971318]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.559328, 10.559615]), '_t': array([ True,  True])}
# [5000], alpha=0.086, {'r': array([243.44837133, 490.92431757]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.452473, 10.452424]), '_t': array([ True,  True])}
# [6000], alpha=0.055, {'r': array([346.24003196, 354.74078078]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([12.398275, 12.398487]), '_t': array([ True,  True])}
# [7000], alpha=0.037, {'r': array([225.60564004, 405.89630067]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([15.222662, 15.222895]), '_t': array([ True,  True])}
# [8000], alpha=0.025, {'r': array([187.00129251, 207.73724801]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([12.36414 , 12.363988]), '_t': array([ True,  True])}
# [9000], alpha=0.017, {'r': array([286.00799948, 185.55474347]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.902154, 10.902148]), '_t': array([ True,  True])}
# [10000], alpha=0.012, {'r': array([473.93868255, 300.39751223]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.729324, 10.729402]), '_t': array([ True,  True])}
# [11000], alpha=0.009, {'r': array([276.92443465, 374.58815784]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.28308 , 11.283162]), '_t': array([ True,  True])}
# [12000], alpha=0.006, {'r': array([504.31189941, 562.21713262]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.570182, 11.570245]), '_t': array([ True,  True])}
# [13000], alpha=0.005, {'r': array([307.53502656, 385.76269673]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.197681, 11.197704]), '_t': array([ True,  True])}
# [14000], alpha=0.004, {'r': array([443.45145974, 526.08107128]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.037451, 10.037471]), '_t': array([ True,  True])}
# [15000], alpha=0.003, {'r': array([466.08995216, 563.6589142 ]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.287298, 10.287483]), '_t': array([ True,  True])}
# [16000], alpha=0.002, {'r': array([535.32460471, 542.71400173]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.215638, 10.215611]), '_t': array([ True,  True])}
# [17000], alpha=0.002, {'r': array([489.46175024, 610.59257861]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.048101, 10.048196]), '_t': array([ True,  True])}
# [18000], alpha=0.001, {'r': array([652.8476713 , 390.19079463]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.023686, 10.023669]), '_t': array([ True,  True])}
# [19000], alpha=0.001, {'r': array([497.40872423, 537.57332253]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.238279, 10.238367]), '_t': array([ True,  True])}
# [20000], alpha=0.002, {'r': array([298.45486485, 383.58057289]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.157789, 10.157755]), '_t': array([ True,  True])}
# [21000], alpha=0.002, {'r': array([364.03934429, 336.32689772]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.189313, 10.189237]), '_t': array([ True,  True])}
# [22000], alpha=0.002, {'r': array([408.62873667, 562.38067958]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.379224, 10.379326]), '_t': array([ True,  True])}
# [23000], alpha=0.002, {'r': array([432.15643261, 762.78957598]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([12.234265, 12.23437 ]), '_t': array([ True,  True])}
# [24000], alpha=0.003, {'r': array([588.25463411, 740.24530197]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.499392, 10.49957 ]), '_t': array([ True,  True])}
# [25000], alpha=0.003, {'r': array([532.77713399, 535.12274189]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.912012, 11.912064]), '_t': array([ True,  True])}
# [26000], alpha=0.003, {'r': array([713.6214759 , 573.86756617]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.002113, 11.002179]), '_t': array([ True,  True])}
# [27000], alpha=0.004, {'r': array([717.21361415, 667.67955731]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([12.500049, 12.500115]), '_t': array([ True,  True])}
# [28000], alpha=0.004, {'r': array([565.51443351, 361.55843311]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.659318, 10.659365]), '_t': array([ True,  True])}
# [29000], alpha=0.004, {'r': array([317.33304424, 356.58385054]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.246984, 10.247031]), '_t': array([ True,  True])}
# [30000], alpha=0.003, {'r': array([911.77077401, 912.60167807]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([12.651635, 12.651817]), '_t': array([ True,  True])}
# [31000], alpha=0.003, {'r': array([762.84119855, 792.06342169]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.492348, 11.492253]), '_t': array([ True,  True])}
# [32000], alpha=0.003, {'r': array([538.50063673, 553.70784653]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.272107, 11.272025]), '_t': array([ True,  True])}
# [33000], alpha=0.004, {'r': array([740.22868114, 623.68392439]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.150154, 10.150304]), '_t': array([ True,  True])}
# [34000], alpha=0.005, {'r': array([867.2342411 , 873.00152879]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([9.521204, 9.520972]), '_t': array([ True,  True])}
# [35000], alpha=0.006, {'r': array([835.16363775, 911.16419692]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([9.267247, 9.267587]), '_t': array([ True,  True])}
# [36000], alpha=0.006, {'r': array([892.68286889, 896.77154379]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.187483, 10.187828]), '_t': array([ True,  True])}
# [37000], alpha=0.006, {'r': array([991.41713401, 912.50284583]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.27728, 10.27718]), '_t': array([ True,  True])}
# [38000], alpha=0.006, {'r': array([986.69335007, 986.17545769]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.646473, 10.646356]), '_t': array([ True,  True])}
# [39000], alpha=0.005, {'r': array([982.37547221, 980.42926863]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([9.7811  , 9.781178]), '_t': array([ True,  True])}
# [40000], alpha=0.004, {'r': array([969.53288085, 969.78308366]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.753819, 10.753811]), '_t': array([ True,  True])}
# [41000], alpha=0.004, {'r': array([942.87091034, 942.03045664]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([9.97344 , 9.973516]), '_t': array([ True,  True])}
# [42000], alpha=0.004, {'r': array([934.21424123, 935.08934975]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.129898, 11.129932]), '_t': array([ True,  True])}
# [43000], alpha=0.004, {'r': array([929.29825721, 954.57615   ]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.649953, 11.649975]), '_t': array([ True,  True])}
# [44000], alpha=0.005, {'r': array([857.26364019, 890.45544186]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.248775, 10.248844]), '_t': array([ True,  True])}
# [45000], alpha=0.003, {'r': array([979.71151039, 981.37282765]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.588474, 10.588726]), '_t': array([ True,  True])}
# [46000], alpha=0.003, {'r': array([992.01611934, 990.39734292]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([14.71893 , 14.718862]), '_t': array([ True,  True])}
# [47000], alpha=0.003, {'r': array([987.10449221, 988.73871783]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.577875, 10.577901]), '_t': array([ True,  True])}
# [48000], alpha=0.003, {'r': array([988.18745558, 986.59618774]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.188046, 10.18812 ]), '_t': array([ True,  True])}
# [49000], alpha=0.003, {'r': array([987.2018655 , 987.69056844]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.336474, 10.336508]), '_t': array([ True,  True])}
# [50000], alpha=0.002, {'r': array([987.35425502, 988.10845793]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.082367, 11.082469]), '_t': array([ True,  True])}
# [51000], alpha=0.002, {'r': array([987.89764922, 987.80865748]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.037077, 11.037147]), '_t': array([ True,  True])}
# [52000], alpha=0.002, {'r': array([989.63477012, 988.98646318]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([12.596962, 12.597233]), '_t': array([ True,  True])}
# [53000], alpha=0.002, {'r': array([987.95306342, 988.42841303]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([13.974823, 13.974772]), '_t': array([ True,  True])}
# [54000], alpha=0.002, {'r': array([986.47935917, 987.58984131]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([9.982912, 9.9831  ]), '_t': array([ True,  True])}
# [55000], alpha=0.002, {'r': array([989.39656162, 988.02277742]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.656644, 10.656544]), '_t': array([ True,  True])}
# [56000], alpha=0.001, {'r': array([989.27567614, 988.89158803]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.288597, 10.28858 ]), '_t': array([ True,  True])}
# [57000], alpha=0.001, {'r': array([987.96901675, 989.29795637]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([9.782798, 9.782787]), '_t': array([ True,  True])}
# [58000], alpha=0.001, {'r': array([991.41168229, 991.74397581]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([9.953511, 9.953531]), '_t': array([ True,  True])}
# [59000], alpha=0.001, {'r': array([990.87048836, 990.92689356]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([9.757132, 9.757196]), '_t': array([ True,  True])}
# [60000], alpha=0.001, {'r': array([991.26107655, 991.89715489]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([9.855091, 9.855012]), '_t': array([ True,  True])}
# [61000], alpha=0.001, {'r': array([991.12927972, 992.06961787]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.205854, 10.205924]), '_t': array([ True,  True])}
# [62000], alpha=0.001, {'r': array([991.61349204, 991.68562873]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.3069  , 11.307278]), '_t': array([ True,  True])}
# [63000], alpha=0.001, {'r': array([993.2349247, 993.4008399]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([9.707076, 9.706844]), '_t': array([ True,  True])}
# [64000], alpha=0.002, {'r': array([993.34232575, 993.52728391]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.350832, 11.350903]), '_t': array([ True,  True])}
# [65000], alpha=0.003, {'r': array([993.75951205, 993.89549484]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.407731, 11.407822]), '_t': array([ True,  True])}
# [66000], alpha=0.003, {'r': array([994.9142002 , 994.95774747]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.548469, 10.548442]), '_t': array([ True,  True])}
# [67000], alpha=0.004, {'r': array([995.1740047 , 994.43292579]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.756954, 11.757008]), '_t': array([ True,  True])}
# [68000], alpha=0.003, {'r': array([995.67070106, 994.98712751]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.242428, 11.242395]), '_t': array([ True,  True])}
# [69000], alpha=0.004, {'r': array([996.51058042, 994.7749409 ]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.198416, 11.198442]), '_t': array([ True,  True])}
# [70000], alpha=0.003, {'r': array([997.35569707, 997.03598629]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.802971, 10.803015]), '_t': array([ True,  True])}
# [71000], alpha=0.004, {'r': array([997.30999391, 997.08211865]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.468314, 10.468408]), '_t': array([ True,  True])}
# [72000], alpha=0.003, {'r': array([996.97470696, 997.13112128]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.834904, 10.834841]), '_t': array([ True,  True])}
# [73000], alpha=0.004, {'r': array([996.58449065, 996.73905696]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.594817, 10.594883]), '_t': array([ True,  True])}
# [74000], alpha=0.004, {'r': array([997.01318422, 996.9860014 ]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.928889, 10.928957]), '_t': array([ True,  True])}
# [75000], alpha=0.003, {'r': array([997.26342406, 997.22930937]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([13.245072, 13.245257]), '_t': array([ True,  True])}
# [76000], alpha=0.003, {'r': array([997.41237508, 997.20115105]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.477113, 10.4771  ]), '_t': array([ True,  True])}
# [77000], alpha=0.002, {'r': array([997.45939557, 997.06222119]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.709123, 11.709202]), '_t': array([ True,  True])}
# [78000], alpha=0.003, {'r': array([997.87000663, 997.78360179]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.427119, 10.4273  ]), '_t': array([ True,  True])}
# [79000], alpha=0.003, {'r': array([997.24640842, 994.67619606]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.165474, 11.165477]), '_t': array([ True,  True])}
# [80000], alpha=0.003, {'r': array([997.9921498 , 997.90647768]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([12.237305, 12.237587]), '_t': array([ True,  True])}
# [81000], alpha=0.003, {'r': array([997.85754388, 997.899234  ]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.709273, 11.709278]), '_t': array([ True,  True])}
# [82000], alpha=0.003, {'r': array([997.66882223, 997.72974068]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.10923 , 11.109285]), '_t': array([ True,  True])}
# [83000], alpha=0.003, {'r': array([997.80691096, 997.85902401]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.560115, 10.560179]), '_t': array([ True,  True])}
# [84000], alpha=0.003, {'r': array([997.3462635 , 997.48714434]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.083538, 10.083635]), '_t': array([ True,  True])}
# [85000], alpha=0.003, {'r': array([997.72645709, 997.73770291]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.394833, 11.394856]), '_t': array([ True,  True])}
# [86000], alpha=0.003, {'r': array([996.67349413, 997.6923293 ]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([11.36373 , 11.363853]), '_t': array([ True,  True])}
# [87000], alpha=0.003, {'r': array([997.1190946, 997.4005219]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.982588, 10.982577]), '_t': array([ True,  True])}
# [88000], alpha=0.003, {'r': array([997.29061583, 997.03818531]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.845558, 10.845536]), '_t': array([ True,  True])}
# [89000], alpha=0.003, {'r': array([996.63669961, 997.14710802]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.484651, 10.484605]), '_t': array([ True,  True])}
# [90000], alpha=0.003, {'r': array([997.34041598, 997.27997139]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([9.661031, 9.66126 ]), '_t': array([ True,  True])}
# [91000], alpha=0.003, {'r': array([997.4934356 , 997.60670133]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([9.554618, 9.55456 ]), '_t': array([ True,  True])}
# [92000], alpha=0.002, {'r': array([997.60029248, 997.40187924]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.852244, 10.852112]), '_t': array([ True,  True])}
# [93000], alpha=0.002, {'r': array([997.59473701, 997.59554811]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([10.708407, 10.70828 ]), '_t': array([ True,  True])}
# [94000], alpha=0.003, {'r': array([997.94438354, 997.57319845]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([9.629503, 9.629454]), '_t': array([ True,  True])}
# [95000], alpha=0.003, {'r': array([997.33523257, 997.8484854 ]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([9.570688, 9.5711  ]), '_t': array([ True,  True])}
# [96000], alpha=0.003, {'r': array([997.58236462, 997.47195284]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([9.55216 , 9.552005]), '_t': array([ True,  True])}
# [97000], alpha=0.003, {'r': array([997.25458986, 997.48852742]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([8.928473, 8.928519]), '_t': array([ True,  True])}
# [98000], alpha=0.003, {'r': array([997.1431431, 997.3935921]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([8.876401, 8.876529]), '_t': array([ True,  True])}
# [99000], alpha=0.003, {'r': array([997.43807296, 997.52293058]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([8.784783, 8.7848  ]), '_t': array([ True,  True])}
# [100000], alpha=0.003, {'r': array([997.48456914, 997.42846404]), '_r': array([ True,  True]), 'l': array([1000, 1000]), '_l': array([ True,  True]), 't': array([8.993493, 8.993509]), '_t': array([ True,  True])}

# %%
plt.plot(returns)

# %%
agent.save("sac_test_ckpt")
